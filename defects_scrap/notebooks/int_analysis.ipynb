# %% [markdown]
# # Intermediate Model Analysis
# **BRIM Systems** | Prepared by: Brian Davis
#
# ---
#
# ## Purpose
#
# Exploratory analysis against dbt intermediate model output. Reads from the enriched
# fact tables produced by the intermediate layer — where all five source systems are
# joined for the first time — to surface cross-system patterns, validate analytical
# assumptions, and inform mart model and dashboard design.
#
# **Section flow:**
# 1. Configuration & Data Loading
# 2. Intermediate Table Summary (preview, schema/nulls, grain verification)
# 3. Cross-System Correlation Matrix
# 4. Additional Analyses (Defect Rate Analysis, Scrap Cost Attribution, Operator & Certification Analysis)

# %% [markdown]
# ## 0. Environment Setup

# %%
import warnings
from pathlib import Path

import duckdb
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import seaborn as sns
from scipy.stats import linregress, ttest_ind

warnings.filterwarnings("ignore")
pd.set_option("display.max_columns", 60)
pd.set_option("display.max_colwidth", 80)
pd.set_option("display.float_format", "{:,.4f}".format)

BRAND_BLUE   = "#3D5166"
BRAND_ACCENT = "#6B8FA8"
WARN_AMBER   = "#D4881E"
FAIL_RED     = "#B94040"
PASS_GREEN   = "#4A7C59"

plt.rcParams.update({
    "figure.facecolor": "white", "axes.facecolor": "white",
    "axes.edgecolor": "#CCCCCC", "axes.grid": True,
    "grid.color": "#EEEEEE", "grid.linestyle": "-",
    "font.family": "sans-serif", "font.size": 11,
    "axes.titlesize": 13, "axes.titleweight": "bold",
    "axes.labelsize": 11, "xtick.labelsize": 10,
    "ytick.labelsize": 10, "legend.fontsize": 10,
    "figure.dpi": 120,
})

print("Environment ready.")
# Out:
# Environment ready.

# %% [markdown]
# ## 1. Configuration & Data Loading

# %%
# ── Database connection ────────────────────────────────────────────────────
DB_PATH = Path("../data/defects_scrap.duckdb").resolve()

# ── Intermediate table name constants ─────────────────────────────────────
TBL_INT_ORDERS  = "int_quality__orders_enriched"
TBL_INT_SCRAP     = "int_quality__scrap_costs"

# ── Primary keys ───────────────────────────────────────────────────────────
PK_MAP = {
    TBL_INT_ORDERS: "work_order_id",
    TBL_INT_SCRAP:    "scrap_id",
}

# %%
# ── Load tables ───────────────────────────────────────────────────────────
con = duckdb.connect(str(DB_PATH))
dfs = {}

print(f"{'Table':<45} {'Rows':>8}  {'Cols':>5}")
print("-" * 65)

for tbl in [TBL_INT_ORDERS, TBL_INT_SCRAP]:
    df = con.execute(f"SELECT * FROM {tbl}").df()
    dfs[tbl] = df
    print(f"  ✓  {tbl:<42} {len(df):>8,}  {len(df.columns):>5}")

orders = dfs[TBL_INT_ORDERS]
scrap    = dfs[TBL_INT_SCRAP]

print("\nTables loaded successfully.")
# Out:
# Table                                             Rows   Cols
# -----------------------------------------------------------------
#   ✓  int_quality__orders_enriched                  8,597     40
#   ✓  int_quality__scrap_costs                      7,948     32
#
# Tables loaded successfully.

# %% [markdown]
# ## 2. Intermediate Table Summary

# %% [markdown]
# ### 2.1 Preview

# %%
for tbl, df in dfs.items():
    print(f"\n{'='*70}")
    print(f"  {tbl.upper()}  ({len(df):,} rows  x  {len(df.columns)} columns)")
    print(f"{'='*70}")
    display(df.head())
# Out:
# ======================================================================
#   INT_QUALITY__ORDERS_ENRICHED  (8,597 rows  x  40 columns)
# ======================================================================
#   work_order_id inspection_id part_number    customer shift_code complexity  \
# 0      WO-10003        INSP-4      P-1016  Customer G    Shift A        Low
# 1      WO-10005        INSP-6      P-1029  Customer B    Shift B        Low
# 2      WO-10006        INSP-7      P-1029  Customer B    Shift B        Low
# 3      WO-10008        INSP-9      P-1029  Customer B    Shift A        Low
# 4      WO-10009       INSP-10      P-1003  Customer D    Shift A     Medium
#
#   material_type  requires_welding    lot_id order_date        actual_start  \
# 0    14ga Steel             False  LOT-1003 2023-01-02 2023-01-02 07:05:00
# 1    1/4" Plate              True  LOT-1002 2023-01-02 2023-01-02 14:38:00
# 2    1/4" Plate              True  LOT-1002 2023-01-02 2023-01-02 15:53:00
# 3    1/4" Plate              True  LOT-1002 2023-01-03 2023-01-03 07:23:00
# 4    1/4" Plate             False  LOT-1002 2023-01-03 2023-01-03 07:38:00
#
#              inspection_date  quantity_ordered  quantity_inspected  \
# 0 2023-01-02 09:20:01.515735               434                 434
# 1 2023-01-02 18:25:00.019988               283                 283
# 2 2023-01-02 18:11:08.085010                38                  38
# 3 2023-01-03 11:39:51.854126                80                  80
# 4 2023-01-03 12:25:34.201107               205                 205
#
#    quantity_passed  quantity_failed  defect_rate  defect_code disposition  \
# 0              409               25       0.0576     Porosity       Scrap
# 1              271               12       0.0424         Burr      Rework
# 2               38                0       0.0000         None        Pass
# 3               75                5       0.0625  Weld Defect   Use-As-Is
# 4              192               13       0.0634  Dimensional       Scrap
#
#    is_anomalous_timestamp  schedule_variance_hrs  std_labor_hrs inspector_id  \
# 0                   False                      1         4.1300        OP011
# 1                   False                      0         3.6400        OP019
# 2                   False                      0         3.6400        OP008
# 3                   False                      0         3.6400        OP013
# 4                   False                      1         4.6300        OP008
#
#   machine_id       machine_name machine_type  machine_age_years  \
# 0        M05  Welding Station 1      Welding                  6
# 1        M04      Press Brake 2      Bending                  2
# 2        M04      Press Brake 2      Bending                  2
# 3        M06  Welding Station 2      Welding                  4
# 4        M04      Press Brake 2      Bending                  2
#
#   machine_location operator_id    operator_name operator_home_shift  \
# 0            Bay C       OP018     Derek Zuniga             Shift A
# 1            Bay B       OP006  Connie Lawrence             Shift B
# 2            Bay B       OP008       Gina Moore             Shift B
# 3            Bay C       OP013     Lisa Hensley             Shift A
# 4            Bay B       OP005  Cristian Santos             Shift A
#
#   cert_level specialization  welding_cert_current  hire_date  \
# 0    Level 2        Bending                  True 2019-11-12
# 1    Level 1        Bending                  True 2023-09-02
# 2    Level 3        General                  True 2014-09-29
# 3    Level 3        General                  True 2024-11-15
# 4    Level 1        Bending                  True 2024-06-21
#
#    welding_cert_mismatch    supplier lot_cert_status lot_receipt_date  \
# 0                  False  Supplier A       Certified       2023-01-02
# 1                  False  Supplier C       Certified       2023-01-02
# 2                  False  Supplier C       Certified       2023-01-02
# 3                  False  Supplier C       Certified       2023-01-02
# 4                  False  Supplier C       Certified       2023-01-02
#
#    unit_cost_per_lb
# 0            1.4950
# 1            2.3700
# 2            2.3700
# 3            2.3700
# 4            2.3700
# ======================================================================
#   INT_QUALITY__SCRAP_COSTS  (7,948 rows  x  32 columns)
# ======================================================================
#   scrap_id work_order_id inspection_id                 scrap_date  \
# 0  SCRAP-1      WO-10000        INSP-1 2023-01-02 15:43:45.174234
# 1  SCRAP-2      WO-10001        INSP-2 2023-01-02 08:58:55.133478
# 2  SCRAP-3      WO-10002        INSP-3 2023-01-02 17:59:16.221099
# 3  SCRAP-4      WO-10003        INSP-4 2023-01-02 09:20:01.515735
# 4  SCRAP-5      WO-10005        INSP-6 2023-01-02 18:25:00.019988
#
#      scrap_reason  defect_code  quantity_scrapped  quantity_reworked  \
# 0     SETUP_ERROR  Dimensional                  0                  1
# 1  OPERATOR_ERROR  Weld Defect                  9                  4
# 2  OPERATOR_ERROR  Dimensional                  4                  9
# 3   MACHINE_ISSUE     Porosity                 16                  9
# 4     SETUP_ERROR         Burr                  9                  3
#
#    material_cost_per_unit  labor_cost_per_unit  total_scrap_cost part_number  \
# 0                  0.6900              20.1300            0.0000      P-1001
# 1                  6.0600              35.0000          369.5400      P-1032
# 2                  2.1400              32.7900          139.7200      P-1010
# 3                  8.6100              28.0700          586.8800      P-1016
# 4                  1.3000              49.3200          455.5800      P-1029
#
#      customer machine_id       machine_name machine_type  machine_age_years  \
# 0  Customer A        M07      Punch Press 1     Punching                  9
# 1  Customer F        M06  Welding Station 2      Welding                  4
# 2  Customer A        M03      Press Brake 1      Bending                 12
# 3  Customer G        M05  Welding Station 1      Welding                  6
# 4  Customer B        M04      Press Brake 2      Bending                  2
#
#   operator_id    operator_name shift_code complexity  material_type  \
# 0       OP007  Abigail Shaffer    Shift B     Medium     16ga Steel
# 1       OP019     Lisa Jackson    Shift A     Medium  Aluminum 5052
# 2       OP010       Ryan Munoz    Shift B        Low  Stainless 304
# 3       OP018     Derek Zuniga    Shift A        Low     14ga Steel
# 4       OP006  Connie Lawrence    Shift B        Low     1/4" Plate
#
#      supplier    lot_id lot_cert_status  welding_cert_current  \
# 0        None      None            None                 False
# 1        None      None            None                  True
# 2        None      None            None                  True
# 3  Supplier A  LOT-1003       Certified                  True
# 4  Supplier C  LOT-1002       Certified                  True
#
#    welding_cert_mismatch  order_defect_rate order_date        actual_start  \
# 0                   True             0.0400 2023-01-02 2023-01-02 14:37:00
# 1                  False             0.0855 2023-01-02 2023-01-02 07:14:00
# 2                  False             0.2203 2023-01-02 2023-01-02 15:06:00
# 3                  False             0.0576 2023-01-02 2023-01-02 07:05:00
# 4                  False             0.0424 2023-01-02 2023-01-02 14:38:00
#
#                 scrap_date_1 scrap_month
# 0 2023-01-02 15:43:45.174234  2023-01-01
# 1 2023-01-02 08:58:55.133478  2023-01-01
# 2 2023-01-02 17:59:16.221099  2023-01-01
# 3 2023-01-02 09:20:01.515735  2023-01-01
# 4 2023-01-02 18:25:00.019988  2023-01-01

# %% [markdown]
# ### 2.2 Schema & Null Flags

# %%
# ── Null thresholds ────────────────────────────────────────────────────────
NULL_WARN_PCT = 0
NULL_FAIL_PCT = 10.0

# %%
def schema_summary(df):
    rows = []
    for col in df.columns:
        s        = df[col]
        null_ct  = s.isna().sum()
        null_pct = null_ct / len(df) * 100
        rows.append({
            "column":     col,
            "dtype":      str(s.dtype),
            "null_count": null_ct,
            "null_pct":   round(null_pct, 1),
            "n_unique":   s.nunique(dropna=True),
            "sample":     str(s.dropna().iloc[0])[:60] if null_ct < len(df) else "(all null)",
        })
    return pd.DataFrame(rows)

for tbl, df in dfs.items():
    print(f"\n{'='*70}\n  {tbl.upper()}  ({len(df):,} rows, {len(df.columns)} columns)\n{'='*70}")
    display(
        schema_summary(df).style
        .format({"null_pct": "{:.1f}%"})
        .applymap(
            lambda v: "background-color: #F8D7DA" if isinstance(v, float) and v > NULL_FAIL_PCT else
                      "background-color: #FFF3CD" if isinstance(v, float) and v > NULL_WARN_PCT else "",
            subset=["null_pct"]
        )
        .set_properties(**{"font-size": "11px"})
    )
# Out:
# ======================================================================
#   INT_QUALITY__ORDERS_ENRICHED  (8,597 rows, 40 columns)
# ======================================================================
# <style type="text/css">
# #T_af3e3_row0_col0, #T_af3e3_row0_col1, #T_af3e3_row0_col2, #T_af3e3_row0_col3, #T_af3e3_row0_col4, #T_af3e3_row0_col5, #T_af3e3_row1_col0, #T_af3e3_row1_col1, #T_af3e3_row1_col2, #T_af3e3_row1_col3, #T_af3e3_row1_col4, #T_af3e3_row1_col5, #T_af3e3_row2_col0, #T_af3e3_row2_col1, #T_af3e3_row2_col2, #T_af3e3_row2_col3, #T_af3e3_row2_col4, #T_af3e3_row2_col5, #T_af3e3_row3_col0, #T_af3e3_row3_col1, #T_af3e3_row3_col2, #T_af3e3_row3_col3, #T_af3e3_row3_col4, #T_af3e3_row3_col5, #T_af3e3_row4_col0, #T_af3e3_row4_col1, #T_af3e3_row4_col2, #T_af3e3_row4_col3, #T_af3e3_row4_col4, #T_af3e3_row4_col5, #T_af3e3_row5_col0, #T_af3e3_row5_col1, #T_af3e3_row5_col2, #T_af3e3_row5_col3, #T_af3e3_row5_col4, #T_af3e3_row5_col5, #T_af3e3_row6_col0, #T_af3e3_row6_col1, #T_af3e3_row6_col2, #T_af3e3_row6_col3, #T_af3e3_row6_col4, #T_af3e3_row6_col5, #T_af3e3_row7_col0, #T_af3e3_row7_col1, #T_af3e3_row7_col2, #T_af3e3_row7_col3, #T_af3e3_row7_col4, #T_af3e3_row7_col5, #T_af3e3_row8_col0, #T_af3e3_row8_col1, #T_af3e3_row8_col2, #T_af3e3_row8_col4, #T_af3e3_row8_col5, #T_af3e3_row9_col0, #T_af3e3_row9_col1, #T_af3e3_row9_col2, #T_af3e3_row9_col3, #T_af3e3_row9_col4, #T_af3e3_row9_col5, #T_af3e3_row10_col0, #T_af3e3_row10_col1, #T_af3e3_row10_col2, #T_af3e3_row10_col3, #T_af3e3_row10_col4, #T_af3e3_row10_col5, #T_af3e3_row11_col0, #T_af3e3_row11_col1, #T_af3e3_row11_col2, #T_af3e3_row11_col3, #T_af3e3_row11_col4, #T_af3e3_row11_col5, #T_af3e3_row12_col0, #T_af3e3_row12_col1, #T_af3e3_row12_col2, #T_af3e3_row12_col3, #T_af3e3_row12_col4, #T_af3e3_row12_col5, #T_af3e3_row13_col0, #T_af3e3_row13_col1, #T_af3e3_row13_col2, #T_af3e3_row13_col3, #T_af3e3_row13_col4, #T_af3e3_row13_col5, #T_af3e3_row14_col0, #T_af3e3_row14_col1, #T_af3e3_row14_col2, #T_af3e3_row14_col3, #T_af3e3_row14_col4, #T_af3e3_row14_col5, #T_af3e3_row15_col0, #T_af3e3_row15_col1, #T_af3e3_row15_col2, #T_af3e3_row15_col3, #T_af3e3_row15_col4, #T_af3e3_row15_col5, #T_af3e3_row16_col0, #T_af3e3_row16_col1, #T_af3e3_row16_col2, #T_af3e3_row16_col3, #T_af3e3_row16_col4, #T_af3e3_row16_col5, #T_af3e3_row17_col0, #T_af3e3_row17_col1, #T_af3e3_row17_col2, #T_af3e3_row17_col3, #T_af3e3_row17_col4, #T_af3e3_row17_col5, #T_af3e3_row18_col0, #T_af3e3_row18_col1, #T_af3e3_row18_col2, #T_af3e3_row18_col3, #T_af3e3_row18_col4, #T_af3e3_row18_col5, #T_af3e3_row19_col0, #T_af3e3_row19_col1, #T_af3e3_row19_col2, #T_af3e3_row19_col3, #T_af3e3_row19_col4, #T_af3e3_row19_col5, #T_af3e3_row20_col0, #T_af3e3_row20_col1, #T_af3e3_row20_col2, #T_af3e3_row20_col3, #T_af3e3_row20_col4, #T_af3e3_row20_col5, #T_af3e3_row21_col0, #T_af3e3_row21_col1, #T_af3e3_row21_col2, #T_af3e3_row21_col3, #T_af3e3_row21_col4, #T_af3e3_row21_col5, #T_af3e3_row22_col0, #T_af3e3_row22_col1, #T_af3e3_row22_col2, #T_af3e3_row22_col3, #T_af3e3_row22_col4, #T_af3e3_row22_col5, #T_af3e3_row23_col0, #T_af3e3_row23_col1, #T_af3e3_row23_col2, #T_af3e3_row23_col3, #T_af3e3_row23_col4, #T_af3e3_row23_col5, #T_af3e3_row24_col0, #T_af3e3_row24_col1, #T_af3e3_row24_col2, #T_af3e3_row24_col3, #T_af3e3_row24_col4, #T_af3e3_row24_col5, #T_af3e3_row25_col0, #T_af3e3_row25_col1, #T_af3e3_row25_col2, #T_af3e3_row25_col3, #T_af3e3_row25_col4, #T_af3e3_row25_col5, #T_af3e3_row26_col0, #T_af3e3_row26_col1, #T_af3e3_row26_col2, #T_af3e3_row26_col3, #T_af3e3_row26_col4, #T_af3e3_row26_col5, #T_af3e3_row27_col0, #T_af3e3_row27_col1, #T_af3e3_row27_col2, #T_af3e3_row27_col3, #T_af3e3_row27_col4, #T_af3e3_row27_col5, #T_af3e3_row28_col0, #T_af3e3_row28_col1, #T_af3e3_row28_col2, #T_af3e3_row28_col3, #T_af3e3_row28_col4, #T_af3e3_row28_col5, #T_af3e3_row29_col0, #T_af3e3_row29_col1, #T_af3e3_row29_col2, #T_af3e3_row29_col3, #T_af3e3_row29_col4, #T_af3e3_row29_col5, #T_af3e3_row30_col0, #T_af3e3_row30_col1, #T_af3e3_row30_col2, #T_af3e3_row30_col3, #T_af3e3_row30_col4, #T_af3e3_row30_col5, #T_af3e3_row31_col0, #T_af3e3_row31_col1, #T_af3e3_row31_col2, #T_af3e3_row31_col3, #T_af3e3_row31_col4, #T_af3e3_row31_col5, #T_af3e3_row32_col0, #T_af3e3_row32_col1, #T_af3 ...
#   font-size: 11px;
# }
# #T_af3e3_row8_col3, #T_af3e3_row36_col3, #T_af3e3_row37_col3, #T_af3e3_row38_col3, #T_af3e3_row39_col3 {
#   background-color: #FFF3CD;
#   font-size: 11px;
# }
# </style>
# <table id="T_af3e3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_af3e3_level0_col0" class="col_heading level0 col0" >column</th>
#       <th id="T_af3e3_level0_col1" class="col_heading level0 col1" >dtype</th>
#       <th id="T_af3e3_level0_col2" class="col_heading level0 col2" >null_count</th>
#       <th id="T_af3e3_level0_col3" class="col_heading level0 col3" >null_pct</th>
#       <th id="T_af3e3_level0_col4" class="col_heading level0 col4" >n_unique</th>
#       <th id="T_af3e3_level0_col5" class="col_heading level0 col5" >sample</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_af3e3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_af3e3_row0_col0" class="data row0 col0" >work_order_id</td>
#       <td id="T_af3e3_row0_col1" class="data row0 col1" >object</td>
#       <td id="T_af3e3_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_af3e3_row0_col3" class="data row0 col3" >0.0%</td>
#       <td id="T_af3e3_row0_col4" class="data row0 col4" >8597</td>
#       <td id="T_af3e3_row0_col5" class="data row0 col5" >WO-10003</td>
#     </tr>
#     <tr>
#       <th id="T_af3e3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_af3e3_row1_col0" class="data row1 col0" >inspection_id</td>
#       <td id="T_af3e3_row1_col1" class="data row1 col1" >object</td>
#       <td id="T_af3e3_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_af3e3_row1_col3" class="data row1 col3" >0.0%</td>
#       <td id="T_af3e3_row1_col4" class="data row1 col4" >8597</td>
#       <td id="T_af3e3_row1_col5" class="data row1 col5" >INSP-4</td>
#     </tr>
#     <tr>
#       <th id="T_af3e3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_af3e3_row2_col0" class="data row2 col0" >part_number</td>
#       <td id="T_af3e3_row2_col1" class="data row2 col1" >object</td>
#       <td id="T_af3e3_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_af3e3_row2_col3" class="data row2 col3" >0.0%</td>
#       <td id="T_af3e3_row2_col4" class="data row2 col4" >35</td>
#       <td id="T_af3e3_row2_col5" class="data row2 col5" >P-1016</td>
#     </tr>
#     <tr>
#       <th id="T_af3e3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_af3e3_row3_col0" class="data row3 col0" >customer</td>
#       <td id="T_af3e3_row3_col1" class="data row3 col1" >object</td>
#       <td id="T_af3e3_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_af3e3_row3_col3" class="data row3 col3" >0.0%</td>
#       <td id="T_af3e3_row3_col4" class="data row3 col4" >8</td>
#       <td id="T_af3e3_row3_col5" class="data row3 col5" >Customer G</td>
#     </tr>
#     <tr>
#       <th id="T_af3e3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_af3e3_row4_col0" class="data row4 col0" >shift_code</td>
#       <td id="T_af3e3_row4_col1" class="data row4 col1" >object</td>
#       <td id="T_af3e3_row4_col2" class="data row4 col2" >0</td>
# ======================================================================
#   INT_QUALITY__SCRAP_COSTS  (7,948 rows, 32 columns)
# ======================================================================
# <style type="text/css">
# #T_793c0_row0_col0, #T_793c0_row0_col1, #T_793c0_row0_col2, #T_793c0_row0_col3, #T_793c0_row0_col4, #T_793c0_row0_col5, #T_793c0_row1_col0, #T_793c0_row1_col1, #T_793c0_row1_col2, #T_793c0_row1_col3, #T_793c0_row1_col4, #T_793c0_row1_col5, #T_793c0_row2_col0, #T_793c0_row2_col1, #T_793c0_row2_col2, #T_793c0_row2_col3, #T_793c0_row2_col4, #T_793c0_row2_col5, #T_793c0_row3_col0, #T_793c0_row3_col1, #T_793c0_row3_col2, #T_793c0_row3_col3, #T_793c0_row3_col4, #T_793c0_row3_col5, #T_793c0_row4_col0, #T_793c0_row4_col1, #T_793c0_row4_col2, #T_793c0_row4_col3, #T_793c0_row4_col4, #T_793c0_row4_col5, #T_793c0_row5_col0, #T_793c0_row5_col1, #T_793c0_row5_col2, #T_793c0_row5_col3, #T_793c0_row5_col4, #T_793c0_row5_col5, #T_793c0_row6_col0, #T_793c0_row6_col1, #T_793c0_row6_col2, #T_793c0_row6_col3, #T_793c0_row6_col4, #T_793c0_row6_col5, #T_793c0_row7_col0, #T_793c0_row7_col1, #T_793c0_row7_col2, #T_793c0_row7_col3, #T_793c0_row7_col4, #T_793c0_row7_col5, #T_793c0_row8_col0, #T_793c0_row8_col1, #T_793c0_row8_col2, #T_793c0_row8_col3, #T_793c0_row8_col4, #T_793c0_row8_col5, #T_793c0_row9_col0, #T_793c0_row9_col1, #T_793c0_row9_col2, #T_793c0_row9_col3, #T_793c0_row9_col4, #T_793c0_row9_col5, #T_793c0_row10_col0, #T_793c0_row10_col1, #T_793c0_row10_col2, #T_793c0_row10_col3, #T_793c0_row10_col4, #T_793c0_row10_col5, #T_793c0_row11_col0, #T_793c0_row11_col1, #T_793c0_row11_col2, #T_793c0_row11_col3, #T_793c0_row11_col4, #T_793c0_row11_col5, #T_793c0_row12_col0, #T_793c0_row12_col1, #T_793c0_row12_col2, #T_793c0_row12_col3, #T_793c0_row12_col4, #T_793c0_row12_col5, #T_793c0_row13_col0, #T_793c0_row13_col1, #T_793c0_row13_col2, #T_793c0_row13_col3, #T_793c0_row13_col4, #T_793c0_row13_col5, #T_793c0_row14_col0, #T_793c0_row14_col1, #T_793c0_row14_col2, #T_793c0_row14_col3, #T_793c0_row14_col4, #T_793c0_row14_col5, #T_793c0_row15_col0, #T_793c0_row15_col1, #T_793c0_row15_col2, #T_793c0_row15_col3, #T_793c0_row15_col4, #T_793c0_row15_col5, #T_793c0_row16_col0, #T_793c0_row16_col1, #T_793c0_row16_col2, #T_793c0_row16_col3, #T_793c0_row16_col4, #T_793c0_row16_col5, #T_793c0_row17_col0, #T_793c0_row17_col1, #T_793c0_row17_col2, #T_793c0_row17_col3, #T_793c0_row17_col4, #T_793c0_row17_col5, #T_793c0_row18_col0, #T_793c0_row18_col1, #T_793c0_row18_col2, #T_793c0_row18_col3, #T_793c0_row18_col4, #T_793c0_row18_col5, #T_793c0_row19_col0, #T_793c0_row19_col1, #T_793c0_row19_col2, #T_793c0_row19_col3, #T_793c0_row19_col4, #T_793c0_row19_col5, #T_793c0_row20_col0, #T_793c0_row20_col1, #T_793c0_row20_col2, #T_793c0_row20_col3, #T_793c0_row20_col4, #T_793c0_row20_col5, #T_793c0_row21_col0, #T_793c0_row21_col1, #T_793c0_row21_col2, #T_793c0_row21_col3, #T_793c0_row21_col4, #T_793c0_row21_col5, #T_793c0_row22_col0, #T_793c0_row22_col1, #T_793c0_row22_col2, #T_793c0_row22_col4, #T_793c0_row22_col5, #T_793c0_row23_col0, #T_793c0_row23_col1, #T_793c0_row23_col2, #T_793c0_row23_col4, #T_793c0_row23_col5, #T_793c0_row24_col0, #T_793c0_row24_col1, #T_793c0_row24_col2, #T_793c0_row24_col4, #T_793c0_row24_col5, #T_793c0_row25_col0, #T_793c0_row25_col1, #T_793c0_row25_col2, #T_793c0_row25_col3, #T_793c0_row25_col4, #T_793c0_row25_col5, #T_793c0_row26_col0, #T_793c0_row26_col1, #T_793c0_row26_col2, #T_793c0_row26_col3, #T_793c0_row26_col4, #T_793c0_row26_col5, #T_793c0_row27_col0, #T_793c0_row27_col1, #T_793c0_row27_col2, #T_793c0_row27_col3, #T_793c0_row27_col4, #T_793c0_row27_col5, #T_793c0_row28_col0, #T_793c0_row28_col1, #T_793c0_row28_col2, #T_793c0_row28_col3, #T_793c0_row28_col4, #T_793c0_row28_col5, #T_793c0_row29_col0, #T_793c0_row29_col1, #T_793c0_row29_col2, #T_793c0_row29_col3, #T_793c0_row29_col4, #T_793c0_row29_col5, #T_793c0_row30_col0, #T_793c0_row30_col1, #T_793c0_row30_col2, #T_793c0_row30_col3, #T_793c0_row30_col4, #T_793c0_row30_col5, #T_793c0_row31_col0, #T_793c0_row31_col1, #T_793c0_row31_col2, #T_793c0_row31_col3, #T_793c0_row31_col4, #T_793c0_row31_col5 {
#   font-size: 11px;
# }
# #T_793c0_row22_col3, #T_793c0_row23_col3, #T_793c0_row24_col3 {
#   background-color: #FFF3CD;
#   font-size: 11px;
# }
# </style>
# <table id="T_793c0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_793c0_level0_col0" class="col_heading level0 col0" >column</th>
#       <th id="T_793c0_level0_col1" class="col_heading level0 col1" >dtype</th>
#       <th id="T_793c0_level0_col2" class="col_heading level0 col2" >null_count</th>
#       <th id="T_793c0_level0_col3" class="col_heading level0 col3" >null_pct</th>
#       <th id="T_793c0_level0_col4" class="col_heading level0 col4" >n_unique</th>
#       <th id="T_793c0_level0_col5" class="col_heading level0 col5" >sample</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_793c0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_793c0_row0_col0" class="data row0 col0" >scrap_id</td>
#       <td id="T_793c0_row0_col1" class="data row0 col1" >object</td>
#       <td id="T_793c0_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_793c0_row0_col3" class="data row0 col3" >0.0%</td>
#       <td id="T_793c0_row0_col4" class="data row0 col4" >7948</td>
#       <td id="T_793c0_row0_col5" class="data row0 col5" >SCRAP-1</td>
#     </tr>
#     <tr>
#       <th id="T_793c0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_793c0_row1_col0" class="data row1 col0" >work_order_id</td>
#       <td id="T_793c0_row1_col1" class="data row1 col1" >object</td>
#       <td id="T_793c0_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_793c0_row1_col3" class="data row1 col3" >0.0%</td>
#       <td id="T_793c0_row1_col4" class="data row1 col4" >7340</td>
#       <td id="T_793c0_row1_col5" class="data row1 col5" >WO-10000</td>
#     </tr>
#     <tr>
#       <th id="T_793c0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_793c0_row2_col0" class="data row2 col0" >inspection_id</td>
#       <td id="T_793c0_row2_col1" class="data row2 col1" >object</td>
#       <td id="T_793c0_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_793c0_row2_col3" class="data row2 col3" >0.0%</td>
#       <td id="T_793c0_row2_col4" class="data row2 col4" >7948</td>
#       <td id="T_793c0_row2_col5" class="data row2 col5" >INSP-1</td>
#     </tr>
#     <tr>
#       <th id="T_793c0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_793c0_row3_col0" class="data row3 col0" >scrap_date</td>
#       <td id="T_793c0_row3_col1" class="data row3 col1" >datetime64[us]</td>
#       <td id="T_793c0_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_793c0_row3_col3" class="data row3 col3" >0.0%</td>
#       <td id="T_793c0_row3_col4" class="data row3 col4" >7948</td>
#       <td id="T_793c0_row3_col5" class="data row3 col5" >2023-01-02 15:43:45.174234</td>
#     </tr>
#     <tr>
#       <th id="T_793c0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_793c0_row4_col0" class="data row4 col0" >scrap_reason</td>
#       <td id="T_793c0_row4_col1" class="data row4 col1" >object</td>
#       <td id="T_793c0_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_793c0_row4_col3" class="data row4 col3" >0.0%</td>
#       <td id="T_793c0_row4_col4" class="data row4 col4" >6</td>
#       <td id="T_793c0_row4_col5" class="data row4 col5" >SETUP_ERROR</td>
#     </tr>
#     <tr>
#       <th id="T_793c0_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_793c0_row5_col0" class="data row5 col0" >defect_code</td>
#       <td id="T_793c0_row5_col1" class="data row5 col1" >object</td>
#       <td id="T_793c0_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_793c0_row5_col3" class="data row5 col3" >0.0%</td>
#       <td id="T_793c0_row5_col4" class="data row5 col4" >7</td>
#       <td id="T_793c0_row5_col5" class="data row5 col5" >Dimensional</td>
#     </tr>
#     <tr>
#       <th id="T_793c0_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_793c0_row6_col0" class="data row6 col0" >quantity_scrapped</td>
#       <td id="T_793c0_row6_col1" class="data row6 col1" >int32</td>
#       <td id="T_793c0_row6_c

# %% [markdown]
# ### 2.3 Grain Verification
#
# Confirms the join logic in the intermediate models did not introduce fanout.
# Each model should retain exactly one row per its declared grain.

# %%
print(f"{'Table':<45} {'PK':<22} {'Total':>8}  {'Unique':>8}  {'Dupes':>8}  Status")
print("-" * 100)

for tbl, pk in PK_MAP.items():
    df      = dfs[tbl]
    total   = len(df)
    unique  = df[pk].nunique()
    dupes   = total - unique
    status  = "✓ PASS" if dupes == 0 else "✗ FAIL — join introduced fanout"
    print(f"  {status[:1]}  {tbl:<42} {pk:<22} {total:>8,}  {unique:>8,}  {dupes:>8,}  {status}")
# Out:
# Table                                         PK                        Total    Unique     Dupes  Status
# ----------------------------------------------------------------------------------------------------
#   ✓  int_quality__orders_enriched               work_order_id             8,597     8,597         0  ✓ PASS
#   ✓  int_quality__scrap_costs                   scrap_id                  7,948     7,948         0  ✓ PASS

# %% [markdown]
# ---
# ## 3. Cross-System Correlation Matrix

# %%
# ── Columns to include in correlation matrix ──────────────────────────────
# Boolean and binary columns are cast to int (0/1) so they appear in the matrix.
# Non-numeric and high-cardinality ID columns are excluded.
CORR_EXCLUDE = [
    "work_order_id", "inspection_id", "part_number", "customer",
    "machine_id", "operator_id", "lot_id", "inspector_id",
    "machine_name", "operator_name", "machine_location",
    "defect_code", "disposition", "material_type",
    "shift_code", "complexity", "supplier", "lot_cert_status",
    "specialization", "cert_level", "operator_home_shift",
]

corr_df = orders.copy()

# Cast boolean columns to int
bool_cols = corr_df.select_dtypes(include="bool").columns.tolist()
for col in bool_cols:
    corr_df[col] = corr_df[col].astype(int)

# Drop excluded and non-numeric columns
corr_df = corr_df.drop(columns=[c for c in CORR_EXCLUDE if c in corr_df.columns], errors="ignore")
corr_df = corr_df.select_dtypes(include="number")

print(f"Columns included in correlation matrix ({len(corr_df.columns)}):")
print(corr_df.columns.tolist())
# Out:
# Columns included in correlation matrix (13):
# ['requires_welding', 'quantity_ordered', 'quantity_inspected', 'quantity_passed', 'quantity_failed', 'defect_rate', 'is_anomalous_timestamp', 'schedule_variance_hrs', 'std_labor_hrs', 'machine_age_years', 'welding_cert_current', 'welding_cert_mismatch', 'unit_cost_per_lb']

# %%
corr_matrix = corr_df.corr()

fig, ax = plt.subplots(figsize=(max(8, len(corr_df.columns) * 1.1),
                                max(6, len(corr_df.columns) * 0.9)))
sns.heatmap(
    corr_matrix, ax=ax,
    annot=True, fmt=".2f",
    cmap="coolwarm", center=0,
    linewidths=0.5, linecolor="white",
    vmin=-1, vmax=1,
    annot_kws={"size": 9}
)
ax.set_title("Cross-System Numeric Correlation Matrix — int_quality__orders_enriched")
plt.tight_layout()
plt.show()

# ── Highlight strongest correlations with defect_rate ─────────────────────
if "defect_rate" in corr_matrix.columns:
    dr_corr = (
        corr_matrix["defect_rate"]
        .drop("defect_rate")
        .abs()
        .sort_values(ascending=False)
    )
    print("\nCorrelations with defect_rate (absolute value, descending):")
    print(dr_corr.to_string())
# Out:
# Correlations with defect_rate (absolute value, descending):
# quantity_failed          0.6906
# machine_age_years        0.3213
# welding_cert_current     0.2052
# welding_cert_mismatch    0.1543
# quantity_passed          0.0968
# std_labor_hrs            0.0570
# unit_cost_per_lb         0.0183
# requires_welding         0.0176
# is_anomalous_timestamp   0.0099
# schedule_variance_hrs    0.0079
# quantity_inspected       0.0026
# quantity_ordered         0.0026

# %% [markdown]
# ---
# ## 4. Defect Rate Analysis

# %%
# ── Analysis config ───────────────────────────────────────────────────────
# Minimum work orders per group to include in rate analysis.
# Groups below this threshold are shown but flagged as low-n.
MIN_GROUP_SIZE = 10

# Working dataframe — exclude rows with null defect_rate (uninspected)
df_dr = orders.dropna(subset=["defect_rate"]).copy()
print(f"Rows with valid defect_rate: {len(df_dr):,} of {len(orders):,}")
# Out:
# Rows with valid defect_rate: 8,597 of 8,597

# %% [markdown]
# ### 4.1 Overall Defect Rate Distribution

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 4))

# Histogram
axes[0].hist(df_dr["defect_rate"], bins=50, color=BRAND_BLUE,
             edgecolor="white", linewidth=0.3)
axes[0].axvline(df_dr["defect_rate"].mean(), color=WARN_AMBER,
                linestyle="--", linewidth=1.5,
                label=f"Mean ({df_dr['defect_rate'].mean():.3f})")
axes[0].axvline(df_dr["defect_rate"].median(), color=FAIL_RED,
                linestyle="--", linewidth=1.5,
                label=f"Median ({df_dr['defect_rate'].median():.3f})")
axes[0].set_title("Defect Rate Distribution")
axes[0].set_xlabel("Defect Rate")
axes[0].set_ylabel("Work Orders")
axes[0].legend()

# Box plot
axes[1].boxplot(df_dr["defect_rate"], vert=True, patch_artist=True,
                boxprops=dict(facecolor=BRAND_ACCENT, color=BRAND_BLUE),
                medianprops=dict(color=WARN_AMBER, linewidth=2),
                flierprops=dict(marker="o", markersize=3,
                                markerfacecolor=FAIL_RED, alpha=0.4))
axes[1].set_title("Defect Rate Box Plot")
axes[1].set_ylabel("Defect Rate")

plt.suptitle("Overall Defect Rate — int_quality__orders_enriched",
             fontsize=13, fontweight="bold")
plt.tight_layout()
plt.show()

# Summary stats
print("\nSummary statistics — defect_rate:")
print(df_dr["defect_rate"].describe().to_string())
# Out:
# Summary statistics — defect_rate:
# count   8,597.0000
# mean        0.0741
# std         0.0531
# min         0.0000
# 25%         0.0476
# 50%         0.0600
# 75%         0.0826
# max         0.6364

# %% [markdown]
# ### 4.2 Defect Rate by Dimension
#
# One chart per pattern dimension. Each chart shows mean defect rate per group
# with group size (n) annotated. Groups below `MIN_GROUP_SIZE` are flagged.

# %%
def defect_rate_by_dimension(df, dim_col, title, highlight_col=None):
    """
    Bar chart of mean defect rate grouped by dim_col.
    Annotates each bar with group size. Highlights a specific group if provided.
    """
    grouped = (
        df.groupby(dim_col)["defect_rate"]
        .agg(mean_defect_rate="mean", n="count")
        .reset_index()
        .sort_values("mean_defect_rate", ascending=False)
    )
    grouped["low_n"] = grouped["n"] < MIN_GROUP_SIZE

    colors = []
    for _, row in grouped.iterrows():
        if row["low_n"]:
            colors.append(WARN_AMBER)
        elif highlight_col and row[dim_col] == highlight_col:
            colors.append(FAIL_RED)
        else:
            colors.append(BRAND_BLUE)

    fig, ax = plt.subplots(figsize=(max(8, len(grouped) * 1.2), 5))
    bars = ax.bar(range(len(grouped)), grouped["mean_defect_rate"],
                  color=colors, width=0.65)

    # Annotate bars with n
    for i, (_, row) in enumerate(grouped.iterrows()):
        label = f"n={row['n']:,}"
        if row["low_n"]:
            label += " ⚠"
        ax.text(i, row["mean_defect_rate"] + 0.001, label,
                ha="center", va="bottom", fontsize=9)

    ax.set_xticks(range(len(grouped)))
    ax.set_xticklabels(grouped[dim_col].astype(str), rotation=30, ha="right")
    ax.set_ylabel("Mean Defect Rate")
    ax.set_title(title)
    ax.yaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f"{x:.3f}"))

    # Overall mean reference line
    overall_mean = df["defect_rate"].mean()
    ax.axhline(overall_mean, color=WARN_AMBER, linestyle="--", linewidth=1.2,
               label=f"Overall mean ({overall_mean:.3f})")
    ax.legend()
    plt.tight_layout()
    plt.show()

    print(f"\n{title} — group summary:")
    display(grouped.reset_index(drop=True))

# %%
# ── P1: Machine Type × Shift Code ─────────────────────────────────────────
df_p1 = df_dr.copy()
df_p1["machine_x_shift"] = df_p1["machine_type"] + " | " + df_p1["shift_code"].fillna("(no shift)")

defect_rate_by_dimension(
    df_p1, "machine_x_shift",
    "P1 — Mean Defect Rate by Machine Type × Shift",
    highlight_col="Press Brake | Shift B"
)
# Out:
# P1 — Mean Defect Rate by Machine Type × Shift — group summary:
#            machine_x_shift  mean_defect_rate     n  low_n
# 0        Bending | Shift B            0.1252  1012  False
# 1        Welding | Shift B            0.0763  1672  False
# 2       Punching | Shift B            0.0725   564  False
# 3       Punching | Shift A            0.0697   543  False
# 4        Welding | Shift A            0.0659  1645  False
# 5  Laser Cutting | Shift A            0.0627  1072  False
# 6  Laser Cutting | Shift B            0.0619  1024  False
# 7        Bending | Shift A            0.0611  1065  False

# %%
# ── P2: Supplier ──────────────────────────────────────────────────────────
defect_rate_by_dimension(
    df_dr.dropna(subset=["supplier"]),
    "supplier",
    "P2 — Mean Defect Rate by Supplier",
)
# Out:
# P2 — Mean Defect Rate by Supplier — group summary:
#      supplier  mean_defect_rate     n  low_n
# 0  Supplier C            0.0897  2197  False
# 1  Supplier A            0.0698  2810  False
# 2  Supplier B            0.0685  2727  False
# 3  Supplier D            0.0658   809  False

# %%
# ── P3: Complexity ────────────────────────────────────────────────────────
defect_rate_by_dimension(
    df_dr,
    "complexity",
    "P3 — Mean Defect Rate by Part Complexity",
)
# Out:
# P3 — Mean Defect Rate by Part Complexity — group summary:
#   complexity  mean_defect_rate     n  low_n
# 0       High            0.1273  1215  False
# 1        Low            0.0713  2679  False
# 2     Medium            0.0619  4703  False

# %%
# ── P4: Welding Cert Mismatch ─────────────────────────────────────────────
df_p4 = df_dr[df_dr["requires_welding"] == True].copy()
df_p4["cert_status"] = df_p4["welding_cert_mismatch"].map(
    {True: "Cert Lapsed", False: "Cert Current"}
)

defect_rate_by_dimension(
    df_p4,
    "cert_status",
    "P4 — Mean Defect Rate by Welding Cert Status (Welding Jobs Only)",
)
# Out:
# P4 — Mean Defect Rate by Welding Cert Status (Welding Jobs Only) — group summary:
#     cert_status  mean_defect_rate     n  low_n
# 0   Cert Lapsed            0.1189   278  False
# 1  Cert Current            0.0715  3215  False

# %% [markdown]
# ---
# ## 5. Scrap Cost Attribution
#
# Total and average scrap costs broken down by the key analytical dimensions.
# Cross-references defect rate with cost impact — a high defect rate dimension
# is not necessarily the highest cost dimension if the affected parts have low
# material or labor values.

# %%
# ── Time series config ────────────────────────────────────────────────────
# Numeric columns to plot as monthly time series against scrap_month.
SCRAP_TIME_SERIES_METRICS = ["total_scrap_cost", "quantity_scrapped"]

# %% [markdown]
# ### 5.1 Total Scrap Cost by Dimension

# %%
def scrap_cost_by_dimension(df, dim_col, title):
    """Bar chart of total and mean scrap cost grouped by dim_col."""
    grouped = (
        df.groupby(dim_col)["total_scrap_cost"]
        .agg(total_cost="sum", mean_cost="mean", n="count")
        .reset_index()
        .sort_values("total_cost", ascending=False)
    )

    fig, axes = plt.subplots(1, 2, figsize=(14, 5))

    # Total cost
    axes[0].bar(range(len(grouped)), grouped["total_cost"],
                color=BRAND_BLUE, width=0.65)
    axes[0].set_xticks(range(len(grouped)))
    axes[0].set_xticklabels(grouped[dim_col].astype(str), rotation=30, ha="right")
    axes[0].set_ylabel("Total Scrap Cost ($)")
    axes[0].set_title("Total Scrap Cost")
    axes[0].yaxis.set_major_formatter(
        mticker.FuncFormatter(lambda x, _: f"${x:,.0f}")
    )

    # Mean cost per event
    axes[1].bar(range(len(grouped)), grouped["mean_cost"],
                color=BRAND_ACCENT, width=0.65)
    axes[1].set_xticks(range(len(grouped)))
    axes[1].set_xticklabels(grouped[dim_col].astype(str), rotation=30, ha="right")
    axes[1].set_ylabel("Mean Cost per Scrap Event ($)")
    axes[1].set_title("Mean Scrap Cost per Event")
    axes[1].yaxis.set_major_formatter(
        mticker.FuncFormatter(lambda x, _: f"${x:,.0f}")
    )

    plt.suptitle(title, fontsize=13, fontweight="bold")
    plt.tight_layout()
    plt.show()

    print(f"\n{title} — group summary:")
    display(grouped.reset_index(drop=True))

scrap_cost_by_dimension(scrap, "machine_type",  "Scrap Cost by Machine Type")
scrap_cost_by_dimension(scrap, "supplier",      "Scrap Cost by Supplier")
scrap_cost_by_dimension(scrap, "complexity",    "Scrap Cost by Complexity")
scrap_cost_by_dimension(scrap, "shift_code",    "Scrap Cost by Shift")
# Out:
# Scrap Cost by Machine Type — group summary:
#     machine_type     total_cost  mean_cost     n
# 0        Welding 1,494,797.2200   487.2220  3068
# 1        Bending 1,247,435.4600   660.0188  1890
# 2  Laser Cutting   783,454.9000   400.9493  1954
# 3       Punching   476,133.4200   459.5882  1036
# Scrap Cost by Supplier — group summary:
#      supplier     total_cost  mean_cost     n
# 0  Supplier C 1,229,181.7700   603.7239  2036
# 1  Supplier A 1,225,314.5300   471.4561  2599
# 2  Supplier B 1,192,886.5100   474.1202  2516
# 3  Supplier D   330,192.9500   444.4050   743
# Scrap Cost by Complexity — group summary:
#   complexity     total_cost  mean_cost     n
# 0     Medium 1,804,994.8700   417.6295  4322
# 1        Low 1,227,544.6500   495.9776  2475
# 2       High   969,281.4800   842.1212  1151
# Scrap Cost by Shift — group summary:
#   shift_code     total_cost  mean_cost     n
# 0    Shift B 2,307,378.4900   578.0006  3992
# 1    Shift A 1,694,442.5100   428.3222  3956

# %% [markdown]
# ### 5.2 Defect Rate vs Scrap Cost Scatter

# %%
# Join mean defect rate per work order to total scrap cost per work order.
# Each point is one work order.
scatter_df = (
    scrap.groupby("work_order_id")["total_scrap_cost"].sum()
    .reset_index()
    .merge(
        orders[["work_order_id", "defect_rate", "machine_type",
                  "complexity", "supplier"]].dropna(subset=["defect_rate"]),
        on="work_order_id", how="inner"
    )
)

fig, ax = plt.subplots(figsize=(10, 6))
ax.scatter(scatter_df["defect_rate"], scatter_df["total_scrap_cost"],
           alpha=0.4, s=20, color=BRAND_BLUE)

# Trend line
x = scatter_df["defect_rate"].values
y = scatter_df["total_scrap_cost"].values
slope, intercept, r, _, _ = linregress(x, y)
x_line = np.linspace(x.min(), x.max(), 100)
ax.plot(x_line, slope * x_line + intercept, color=FAIL_RED,
        linewidth=1.5, linestyle="--", label=f"Trend (r={r:.2f})")

ax.set_xlabel("Defect Rate")
ax.set_ylabel("Total Scrap Cost per Work Order ($)")
ax.set_title("Defect Rate vs Total Scrap Cost — per Work Order")
ax.yaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f"${x:,.0f}"))
ax.legend()
plt.tight_layout()
plt.show()

print(f"Pearson r (defect_rate vs total_scrap_cost): {r:.3f}")
# Out:
# Pearson r (defect_rate vs total_scrap_cost): 0.529

# %% [markdown]
# ### 5.3 Monthly Scrap Cost Trend

# %%
for metric in SCRAP_TIME_SERIES_METRICS:
    if metric not in scrap.columns:
        print(f"Column {metric} not found — skipping.")
        continue

    monthly = (
        scrap.groupby("scrap_month")[metric]
        .sum()
        .reset_index()
        .sort_values("scrap_month")
    )
    s   = monthly[metric]
    x_n = np.arange(len(s))
    slope, intercept, _, _, _ = linregress(x_n, s)
    trend = slope * x_n + intercept

    fig, ax = plt.subplots(figsize=(14, 4))
    ax.plot(monthly["scrap_month"].astype(str), s,
            color=BRAND_BLUE, linewidth=2, marker="o", markersize=4)
    ax.axhline(s.mean(), color=WARN_AMBER, linestyle="--", linewidth=1.2,
               label=f"Mean ({s.mean():,.1f})")
    ax.plot(monthly["scrap_month"].astype(str), trend,
            color=FAIL_RED, linewidth=1.5, linestyle="-.",
            label=f"Trend (slope: {slope:+.1f}/mo)")
    ax.set_title(f"Monthly {metric.replace('_', ' ').title()} — Scrap Events")
    ax.set_ylabel(metric.replace("_", " ").title())

    fmt = mticker.FuncFormatter(lambda x, _: f"${x:,.0f}") if "cost" in metric           else mticker.FuncFormatter(lambda x, _: f"{x:,.0f}")
    ax.yaxis.set_major_formatter(fmt)

    xticks = monthly["scrap_month"].astype(str)[::6]
    ax.set_xticks(xticks)
    ax.set_xticklabels(xticks, rotation=45, ha="right")
    ax.legend()
    plt.tight_layout()
    plt.show()

    print(f"\n{metric} — monthly summary:")
    print(f"  Mean:   {s.mean():,.1f}")
    print(f"  Std:    {s.std():,.1f}")
    print(f"  Min:    {s.min():,.1f}  ({monthly.loc[s.idxmin(), 'scrap_month']})")
    print(f"  Max:    {s.max():,.1f}  ({monthly.loc[s.idxmax(), 'scrap_month']})")
    print(f"  Trend:  {slope:+.2f} per month")
# Out:
# total_scrap_cost — monthly summary:
#   Mean:   111,161.7
#   Std:    12,393.3
#   Min:    76,238.4  (2025-06-01 00:00:00)
#   Max:    133,145.9  (2025-08-01 00:00:00)
#   Trend:  +100.55 per month
# quantity_scrapped — monthly summary:
#   Mean:   2,775.2
#   Std:    321.1
#   Min:    1,920.0  (2025-06-01 00:00:00)
#   Max:    3,441.0  (2025-08-01 00:00:00)
#   Trend:  +2.84 per month

# %% [markdown]
# ### 5.4 Top Work Orders by Scrap Cost

# %%
# ── Config ────────────────────────────────────────────────────────────────
TOP_N_ORDERS = 20

top_orders = (
    scrap.groupby("work_order_id")["total_scrap_cost"].sum()
    .reset_index()
    .sort_values("total_scrap_cost", ascending=False)
    .head(TOP_N_ORDERS)
    .merge(
        orders[["work_order_id", "part_number", "machine_type",
                  "shift_code", "operator_id", "supplier",
                  "complexity", "defect_rate", "welding_cert_mismatch"]],
        on="work_order_id", how="left"
    )
)

print(f"Top {TOP_N_ORDERS} work orders by total scrap cost:")
display(top_orders.reset_index(drop=True))
# Out:
# Top 20 work orders by total scrap cost:
#    work_order_id  total_scrap_cost part_number   machine_type shift_code  \
# 0       WO-11087       12,029.3400      P-1021        Bending    Shift B
# 1       WO-13537       11,353.1200      P-1021        Bending    Shift B
# 2       WO-12602        8,752.8600      P-1021        Bending    Shift B
# 3       WO-11690        8,144.5000      P-1022        Bending    Shift B
# 4       WO-10497        7,453.3800      P-1021        Bending    Shift B
# 5       WO-11237        7,408.9200      P-1021        Bending    Shift B
# 6       WO-13696        7,248.5100      P-1021        Bending    Shift B
# 7       WO-17077        6,554.5200      P-1021        Bending    Shift B
# 8       WO-13671        6,264.1700      P-1021        Bending    Shift B
# 9       WO-11912        6,132.7200      P-1011        Welding    Shift B
# 10      WO-11884        5,695.2000      P-1000        Bending    Shift B
# 11      WO-17924        5,663.8000      P-1021        Bending    Shift B
# 12      WO-11638        5,533.8000      P-1007  Laser Cutting    Shift A
# 13      WO-17402        5,383.0300      P-1004        Welding    Shift B
# 14      WO-18389        5,201.4900      P-1021        Bending    Shift B
# 15      WO-16521        5,179.0200      P-1010        Bending    Shift B
# 16      WO-13120        5,107.3400      P-1021        Bending    Shift B
# 17      WO-18138        5,086.0400      P-1010        Bending    Shift B
# 18      WO-16347        5,057.2800      P-1021        Bending    Shift B
# 19      WO-11408        4,840.0800      P-1021        Bending    Shift B
#
#    operator_id    supplier complexity  defect_rate  welding_cert_mismatch
# 0        OP011  Supplier B       High       0.2913                  False
# 1        OP012  Supplier B       High       0.3219                  False
# 2        OP008  Supplier C       High       0.5394                  False
# 3        OP012  Supplier B     Medium       0.1683                  False
# 4        OP014  Supplier C       High       0.5090                  False
# 5        OP006  Supplier A       High       0.3077                  False
# 6        OP003  Supplier A       High       0.2961                  False
# 7        OP012  Supplier C       High       0.5528                  False
# 8        OP006  Supplier D       High       0.3290                  False
# 9        OP007  Supplier A       High       0.1847                   True
# 10       OP014  Supplier A        Low       0.1964                  False
# 11       OP011  Supplier C       High       0.4934                  False
# 12       OP009  Supplier C     Medium       0.1247                  False
# 13       OP007  Supplier B     Medium       0.1438                   True
# 14       OP007  Supplier C       High       0.5213                  False
# 15       OP003  Supplier A        Low       0.1990                  False
# 16       OP003  Supplier C       High       0.5320                  False
# 17       OP016  Supplier A        Low       0.1758                  False
# 18       OP003  Supplier A       High       0.2789                  False
# 19       OP011  Supplier B       High       0.2966                  False

# %% [markdown]
# ---
# ## 6. Operator & Certification Analysis

# %% [markdown]
# ### 6.1 Defect Rate by Operator

# %%
# ── Config ────────────────────────────────────────────────────────────────
MIN_JOBS_OPERATOR = 10  # minimum work orders for an operator to appear in chart

op_summary = (
    df_dr.groupby(["operator_id", "operator_name", "welding_cert_current",
                   "cert_level", "specialization"])["defect_rate"]
    .agg(mean_defect_rate="mean", n_jobs="count")
    .reset_index()
    .sort_values("mean_defect_rate", ascending=False)
)

op_plot = op_summary[op_summary["n_jobs"] >= MIN_JOBS_OPERATOR].copy()
op_plot["label"] = op_plot["operator_id"] + "\n" + op_plot["operator_name"].str.split().str[0]

colors = [
    FAIL_RED if not cert else BRAND_BLUE
    for cert in op_plot["welding_cert_current"]
]

fig, ax = plt.subplots(figsize=(max(10, len(op_plot) * 0.7), 5))
bars = ax.bar(range(len(op_plot)), op_plot["mean_defect_rate"],
              color=colors, width=0.65)

for i, (_, row) in enumerate(op_plot.iterrows()):
    ax.text(i, row["mean_defect_rate"] + 0.001, f"n={row['n_jobs']}",
            ha="center", va="bottom", fontsize=8)

ax.set_xticks(range(len(op_plot)))
ax.set_xticklabels(op_plot["label"], rotation=30, ha="right", fontsize=9)
ax.set_ylabel("Mean Defect Rate")
ax.set_title("Defect Rate by Operator (red = lapsed welding cert)")
ax.axhline(df_dr["defect_rate"].mean(), color=WARN_AMBER, linestyle="--",
           linewidth=1.2, label=f"Overall mean ({df_dr['defect_rate'].mean():.3f})")
ax.yaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f"{x:.3f}"))
ax.legend()
plt.tight_layout()
plt.show()

print("\nOperator summary (all operators with sufficient job volume):")
display(op_plot.drop(columns=["label"]).reset_index(drop=True))
# Out:
# Operator summary (all operators with sufficient job volume):
#    operator_id     operator_name  welding_cert_current cert_level  \
# 0        OP007   Abigail Shaffer                 False    Level 1
# 1        OP012      Jamie Arnold                  True    Level 3
# 2        OP003   Angie Henderson                  True    Level 2
# 3        OP006   Connie Lawrence                  True    Level 1
# 4        OP001      Allison Hill                  True    Level 2
# 5        OP010        Ryan Munoz                  True    Level 2
# 6        OP016     Brian Ramirez                  True    Level 1
# 7        OP011    Monica Herrera                  True    Level 1
# 8        OP014  Michele Williams                  True    Level 1
# 9        OP008        Gina Moore                  True    Level 3
# 10       OP015      Dylan Miller                  True    Level 1
# 11       OP018      Derek Zuniga                  True    Level 2
# 12       OP004     Daniel Wagner                  True    Level 2
# 13       OP013      Lisa Hensley                  True    Level 3
# 14       OP020        Carla Gray                  True    Level 1
# 15       OP017        Holly Wood                  True    Level 1
# 16       OP002       Noah Rhodes                  True    Level 3
# 17       OP005   Cristian Santos                  True    Level 1
# 18       OP009   Gabrielle Davis                  True    Level 2
# 19       OP019      Lisa Jackson                  True    Level 2
#
#    specialization  mean_defect_rate  n_jobs
# 0         Welding            0.1180     499
# 1           Laser            0.0840     423
# 2         General            0.0823     404
# 3         Bending            0.0800     450
# 4         Welding            0.0792     417
# 5         Bending            0.0788     412
# 6         Bending            0.0781     458
# 7         Bending            0.0776     390
# 8           Laser            0.0775     420
# 9         General            0.0773     399
# 10        Bending            0.0664     393
# 11        Bending            0.0656     437
# 12        Bending            0.0653     459
# 13        General            0.0649     480
# 14        Bending            0.0646     435
# 15        Bending            0.0645     441
# 16        General            0.0643     429
# 17        Bending            0.0641     431
# 18          Laser            0.0626     403
# 19          Laser            0.0614     417

# %% [markdown]
# ### 6.2 Cert Lapsed vs Current — Statistical Comparison

# %%
# Two-sample t-test: defect rate for welding jobs with lapsed cert vs current cert.
# Restricted to welding jobs only (requires_welding = True).
welding_jobs = df_dr[df_dr["requires_welding"] == True].copy()

lapsed  = welding_jobs[welding_jobs["welding_cert_mismatch"] == True]["defect_rate"]
current = welding_jobs[welding_jobs["welding_cert_mismatch"] == False]["defect_rate"]

t_stat, p_val = ttest_ind(lapsed, current, equal_var=False)

print("Welding jobs only — defect rate by certification status:")
print(f"  Cert lapsed  — n={len(lapsed):,}  mean={lapsed.mean():.4f}  std={lapsed.std():.4f}")
print(f"  Cert current — n={len(current):,}  mean={current.mean():.4f}  std={current.std():.4f}")
print(f"\nWelch t-test: t={t_stat:.3f}  p={p_val:.4f}")
print(f"Result: {'Statistically significant (p < 0.05)' if p_val < 0.05 else 'Not significant at p < 0.05'}")

# ── Box plot comparison ────────────────────────────────────────────────────
fig, ax = plt.subplots(figsize=(7, 5))
ax.boxplot(
    [current, lapsed],
    labels=["Cert Current", "Cert Lapsed"],
    patch_artist=True,
    boxprops=dict(facecolor=BRAND_ACCENT),
    medianprops=dict(color=WARN_AMBER, linewidth=2),
    flierprops=dict(marker="o", markersize=3, markerfacecolor=FAIL_RED, alpha=0.4)
)
ax.set_ylabel("Defect Rate")
ax.set_title("P4 — Defect Rate: Cert Current vs Cert Lapsed (Welding Jobs Only)")
ax.yaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f"{x:.3f}"))
plt.tight_layout()
plt.show()
# Out:
# Welding jobs only — defect rate by certification status:
#   Cert lapsed  — n=278  mean=0.1189  std=0.0594
#   Cert current — n=3,215  mean=0.0715  std=0.0413
#
# Welch t-test: t=13.068  p=0.0000
# Result: Statistically significant (p < 0.05)

# %% [markdown]
# ### 6.3 OP007 Spotlight

# %%
# ── Config ────────────────────────────────────────────────────────────────
SPOTLIGHT_OPERATOR = "OP007"

op_df  = df_dr[df_dr["operator_id"] == SPOTLIGHT_OPERATOR]
all_df = df_dr[df_dr["operator_id"] != SPOTLIGHT_OPERATOR]

if op_df.empty:
    print(f"No records found for operator {SPOTLIGHT_OPERATOR}.")
else:
    print(f"Operator {SPOTLIGHT_OPERATOR} summary:")
    print(f"  Total work orders:   {len(op_df):,}")
    print(f"  Mean defect rate:    {op_df['defect_rate'].mean():.4f}")
    print(f"  All others mean:     {all_df['defect_rate'].mean():.4f}")
    print(f"  Multiplier:          {op_df['defect_rate'].mean() / all_df['defect_rate'].mean():.2f}x")
    print(f"  Welding cert status: {op_df['welding_cert_current'].iloc[0]}")
    print(f"  Cert level:          {op_df['cert_level'].iloc[0]}")
    print(f"  Specialization:      {op_df['specialization'].iloc[0]}")

    print(f"\n{SPOTLIGHT_OPERATOR} — defect rate by machine type:")
    display(
        op_df.groupby("machine_type")["defect_rate"]
        .agg(mean_defect_rate="mean", n_jobs="count")
        .sort_values("mean_defect_rate", ascending=False)
        .reset_index()
    )
# Out:
# Operator OP007 summary:
#   Total work orders:   499
#   Mean defect rate:    0.1180
#   All others mean:     0.0714
#   Multiplier:          1.65x
#   Welding cert status: False
#   Cert level:          Level 1
#   Specialization:      Welding
#
# OP007 — defect rate by machine type:
#     machine_type  mean_defect_rate  n_jobs
# 0        Welding            0.1424     241
# 1        Bending            0.1343     107
# 2       Punching            0.0752      54
# 3  Laser Cutting            0.0633      97
